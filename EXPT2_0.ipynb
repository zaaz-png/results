# %%
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import files
uploaded=files.upload()

data=pd.read_csv("dataset2.csv")
# Out:
#      <input type="file" id="files-e820e994-bd10-437c-ab33-66c0894e6976" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e820e994-bd10-437c-ab33-66c0894e6976">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data.head(2)
# Out:
#    Patient ID  Age  Blood Pressure  Urine Specific Gravity  Albumin in urine  \
# 0           0   48             178                   10.10               2.0
# 1           1    7             138                   10.14               1.0
#
#    Sugar in urine       RBC Puss cells Pus cells clumps Bacteria  ...  \
# 0               2  abnormal   abnormal          present  present  ...
# 1               4  abnormal   abnormal          present  present  ...
#
#    Urea in blood  Serum Creatinine  Sodium in blood  Potassium in blood  \
# 0          195.0              9.08            124.0                 6.0
# 1          111.0              7.88            133.0                 6.8
#
#    Hemoglobin  Packed corpuscular volume  WBC count  RBC count  Apetite  \
# 0         8.0                       25.0      11319        3.8     poor
# 1        11.0                       27.0      11018        2.9     poor
#
#   Chronic kidney failure
# 0                    yes
# 1                    yes
#
# ...

# %% [markdown]
# s=pd.Series(data= NaN, index=[49,48,47,1,2,3,4,9])
# here the indixes that we have assigned are called labels. labels are also associated with the original indices values of the list.
#
# s.iloc[:3]: slice first 3 rows. refers default index values which start with zero.. of series(not of labels)
# s.loc[:3]: slice upto and including. it traverses through the series until the index value doesn't match the label value (i.e till 3)
#
# series mein... slicing operation on LABELS(user defined indices) happens from START TO END LABEL (in index it happens from start to end-1 index.)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15051 entries, 0 to 15050
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient ID                 15051 non-null  int64
#  1   Age                        15051 non-null  int64
#  2   Blood Pressure             15051 non-null  int64
#  3   Urine Specific Gravity     15051 non-null  float64
#  4   Albumin in urine           15051 non-null  float64
#  5   Sugar in urine             15051 non-null  int64
#  6   RBC                        15051 non-null  object
#  7   Puss cells                 15051 non-null  object
#  8   Pus cells clumps           15042 non-null  object
#  9   Bacteria                   15045 non-null  object
#  10  Random blood glucose       15051 non-null  int64
#  11  Urea in blood              15051 non-null  float64
#  12  Serum Creatinine           15042 non-null  float64
# ...

# %%
data.shape
# Out:
# (15051, 21)

# %%
data.describe()
# Out:
#          Patient ID           Age  Blood Pressure  Urine Specific Gravity  \
# count  15051.000000  15051.000000    15051.000000            15051.000000
# mean    7525.000000     52.100458       93.232144               11.287820
# std     4344.993786     17.554229       19.906447                1.522975
# min        0.000000      2.000000       50.000000               10.000000
# 25%     3762.500000     45.000000       80.000000               10.190000
# 50%     7525.000000     55.000000       94.000000               10.240000
# 75%    11287.500000     65.000000      107.000000               12.350000
# max    15050.000000     90.000000      180.000000               15.000000
#
#        Albumin in urine  Sugar in urine  Random blood glucose  Urea in blood  \
# count      15051.000000    15051.000000          15051.000000   15051.000000
# mean         228.358714      154.320710            157.608132      59.652501
# ...

# %%
data['RBC count']
# Out:
# 0        3.8
# 1        2.9
# 2        4.4
# 3        3.2
# 4        3.9
#         ...
# 15046    3.5
# 15047    3.2
# 15048    3.7
# 15049    3.8
# 15050    4.2
# Name: RBC count, Length: 15051, dtype: float64

# %%
data.loc[374, 'Urea in blood']
# Out:
# np.float64(33.0)

# %%
data.iloc[12, 8]
# Out:
# 'present'

# %% [markdown]
# See if any null values are present. Display count of null values.

# %%
data.isnull()
# Out:
#        Patient ID    Age  Blood Pressure  Urine Specific Gravity  \
# 0           False  False           False                   False
# 1           False  False           False                   False
# 2           False  False           False                   False
# 3           False  False           False                   False
# 4           False  False           False                   False
# ...           ...    ...             ...                     ...
# 15046       False  False           False                   False
# 15047       False  False           False                   False
# 15048       False  False           False                   False
# 15049       False  False           False                   False
# 15050       False  False           False                   False
#
#        Albumin in urine  Sugar in urine    RBC  Puss cells  Pus cells clumps  \
# 0                 False           False  False       False             False
# ...

# %%
print(data.isnull().sum())
# Out:
# Patient ID                   0
# Age                          0
# Blood Pressure               0
# Urine Specific Gravity       0
# Albumin in urine             0
# Sugar in urine               0
# RBC                          0
# Puss cells                   0
# Pus cells clumps             9
# Bacteria                     6
# Random blood glucose         0
# Urea in blood                0
# Serum Creatinine             9
# Sodium in blood              0
# Potassium in blood           0
# Hemoglobin                   0
# Packed corpuscular volume    0
# WBC count                    0
# RBC count                    0
# Apetite                      1
# Chronic kidney failure       2
# dtype: int64

# %% [markdown]
# therefore, there are total 27 missing values.

# %% [markdown]
# replacing missing values with mean.

# %%
data['Pus cells clumps'].fillna(data['Pus cells clumps'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_3283/888069267.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Pus cells clumps'].fillna(data['Pus cells clumps'].mode()[0], inplace=True)

# %%
print(data.isnull().sum())
# Out:
# Patient ID                   0
# Age                          0
# Blood Pressure               0
# Urine Specific Gravity       0
# Albumin in urine             0
# Sugar in urine               0
# RBC                          0
# Puss cells                   0
# Pus cells clumps             0
# Bacteria                     0
# Random blood glucose         0
# Urea in blood                0
# Serum Creatinine             0
# Sodium in blood              0
# Potassium in blood           0
# Hemoglobin                   0
# Packed corpuscular volume    0
# WBC count                    0
# RBC count                    0
# Apetite                      0
# Chronic kidney failure       0
# dtype: int64

# %%
data['Bacteria'].fillna(data['Bacteria'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_3283/2605330781.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Bacteria'].fillna(data['Bacteria'].mode()[0], inplace=True)

# %%
data['Serum Creatinine'].fillna(data['Serum Creatinine'].mean(), inplace=True)
# Out:
# /tmp/ipykernel_3283/2698678221.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Serum Creatinine'].fillna(data['Serum Creatinine'].mean(), inplace=True)

# %%
data['Apetite'].fillna(data['Apetite'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_3283/348316318.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Apetite'].fillna(data['Apetite'].mode()[0], inplace=True)

# %%
data['Chronic kidney failure'].fillna(data['Chronic kidney failure'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_3283/3897703642.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Chronic kidney failure'].fillna(data['Chronic kidney failure'].mode()[0], inplace=True)

# %% [markdown]
# ALL MISSING VALUES FILLED.

# %% [markdown]
# conditional filtering

# %%
data[data['Blood Pressure']>170].head(5)
# Out:
#     Patient ID  Age  Blood Pressure  Urine Specific Gravity  Albumin in urine  \
# 0            0   48             178                   10.10               2.0
# 4            4   51             175                   10.15               4.0
# 8            8   52             171                   10.09               1.0
# 17          17   47             177                   10.10               2.0
# 18          18   60             177                   10.13               2.0
#
#     Sugar in urine       RBC Puss cells Pus cells clumps Bacteria  ...  \
# 0                2  abnormal   abnormal          present  present  ...
# 4                5  abnormal   abnormal          present  present  ...
# 8                2  abnormal   abnormal          present  present  ...
# 17               4  abnormal   abnormal          present  present  ...
# 18               2  abnormal   abnormal          present  present  ...
#
# ...

# %%
part= data[data['Sugar in urine']<180]
part[part['Sugar in urine']>60].value_counts().sum()
# Out:
# np.int64(2381)

# %%
part2= part[part['Sugar in urine']>60]
part2['Sugar in urine'].value_counts().sum()
# Out:
# np.int64(2381)

# %%
nan_rows = part2[part2.isnull().any(axis=1)]
display(nan_rows)
# Out:
#        Patient ID  Age  Blood Pressure  Urine Specific Gravity  \
# 8383         8383   46              80                   13.23
# 9719         9719   45              60                   10.50
# 10530       10530   54              70                   14.96
# 10540       10540   45              60                   12.81
# 11492       11492   54              70                   14.76
# 11720       11720   61              90                   10.08
# 12464       12464   45              60                   12.43
#
#        Albumin in urine  Sugar in urine       RBC Puss cells Pus cells clumps  \
# 8383              809.1             173  abnormal     normal          present
# 9719              536.1             126    normal     normal              NaN
# 10530             638.4             171  abnormal   abnormal          present
# 10540             276.5             179  abnormal   abnormal              NaN
# ...

# %%
part2['Sugar in urine'].value_counts().sum()
# Out:
# np.int64(2381)

# %% [markdown]
# 2381 patients have normal urine sugar levels.

# %%
data.loc[5641, 'RBC count']
# Out:
# np.float64(5.1)

# %%
data.iloc[::1000]
# Out:
#        Patient ID  Age  Blood Pressure  Urine Specific Gravity  \
# 0               0   48             178                   10.10
# 1000         1000    8             117                   10.22
# 2000         2000   72             116                   10.22
# 3000         3000   59             101                   10.18
# 4000         4000   42             115                   10.18
# 5000         5000   14             100                   10.23
# 6000         6000   46              92                   10.15
# 7000         7000   68             116                   10.17
# 8000         8000   67              80                   10.48
# 9000         9000   59              70                   14.96
# 10000       10000   73              80                   13.17
# 11000       11000   71              90                   11.29
# 12000       12000   70              90                   11.94
# 13000       13000   48              70                   11.80
# ...

# %%
df1= data[(data['Age']==6) & (data['Chronic kidney failure']=='yes')]
df1[['Age', 'Apetite', 'Urea in blood', 'Chronic kidney failure']]
# Out:
#        Age Apetite  Urea in blood Chronic kidney failure
# 190      6    poor          200.0                    yes
# 2070     6    poor           27.0                    yes
# 3548     6    poor           23.0                    yes
# 7982     6    poor          103.5                    yes
# 9460     6    poor           44.1                    yes
# 10191    6    poor           50.0                    yes
# 10430    6    poor           78.3                    yes
# 11392    6    poor           58.3                    yes

# %% [markdown]
# there are 8 patients of 6 years of age. all the their apetite are poor.

# %%
df2= data[(data['Pus cells clumps']=='present') & (data['Chronic kidney failure']=='yes') & (data['Bacteria']=='present')]
df2[['Age', 'Puss cells', 'Bacteria', 'Pus cells clumps', 'Chronic kidney failure']].head(15)
# Out:
#     Age Puss cells Bacteria Pus cells clumps Chronic kidney failure
# 0    48   abnormal  present          present                    yes
# 1     7   abnormal  present          present                    yes
# 2    62   abnormal  present          present                    yes
# 3    48   abnormal  present          present                    yes
# 4    51   abnormal  present          present                    yes
# 5    60   abnormal  present          present                    yes
# 6    68   abnormal  present          present                    yes
# 7    24   abnormal  present          present                    yes
# 8    52   abnormal  present          present                    yes
# 9    53   abnormal  present          present                    yes
# 10   50   abnormal  present          present                    yes
# 11   63   abnormal  present          present                    yes
# 12   68   abnormal  present          present                    yes
# ...

# %% [markdown]
# all patients having pus cell clumps have abnormal amount of pus cells.

# %%
df3= data[(data['Hemoglobin']<13) & (data['Bacteria']=='present')]
df3[['Age', 'Hemoglobin', 'Bacteria', 'Chronic kidney failure']].head()
# Out:
#    Age  Hemoglobin Bacteria Chronic kidney failure
# 0   48         8.0  present                    yes
# 1    7        11.0  present                    yes
# 2   62         8.0  present                    yes
# 3   48        11.0  present                    yes
# 4   51         9.0  present                    yes

# %% [markdown]
# pateints having bacteria and low haemoglobin levels have vhronic kidney failure.

# %%
data.columns
# Out:
# Index(['Patient ID', 'Age', 'Blood Pressure', 'Urine Specific Gravity',
#        'Albumin in urine', 'Sugar in urine', 'RBC', 'Puss cells',
#        'Pus cells clumps', 'Bacteria', 'Random blood glucose', 'Urea in blood',
#        'Serum Creatinine', 'Sodium in blood', 'Potassium in blood',
#        'Hemoglobin', 'Packed corpuscular volume', 'WBC count', 'RBC count',
#        'Apetite', 'Chronic kidney failure'],
#       dtype='object')

# %%
data.groupby('Urea in blood').agg({'Sodium in blood':'mean'}).head()
# Out:
#                Sodium in blood
# Urea in blood
# 10.0                140.103053
# 11.0                139.852000
# 12.0                139.608511
# 13.0                140.016736
# 14.0                140.239216

# %%
data.groupby('Bacteria').agg({'Age':'mean'})
# Out:
#                 Age
# Bacteria
# absent    51.626056
# present   57.053313

# %% [markdown]
# for anemia risk:
# ratio of Packed Corpuscular Volume to haemoglobin should be around 3. more or less then that is abnormal

# %%
data['PVC_Hb ratio']= data['Packed corpuscular volume']/data['Hemoglobin']
data['PVC_Hb ratio'].head()
# Out:
# 0    3.125000
# 1    2.454545
# 2    3.375000
# 3    3.181818
# 4    3.333333
# Name: PVC_Hb ratio, dtype: float64

# %%
data['Anemia risk']= np.where((data['PVC_Hb ratio']>2.7) & (data['PVC_Hb ratio']<3.3), 'low', 'high')
data['Anemia risk'].head()
# Out:
# 0     low
# 1    high
# 2    high
# 3     low
# 4    high
# Name: Anemia risk, dtype: object

# %%
data.columns
# Out:
# Index(['Patient ID', 'Age', 'Blood Pressure', 'Urine Specific Gravity',
#        'Albumin in urine', 'Sugar in urine', 'RBC', 'Puss cells',
#        'Pus cells clumps', 'Bacteria', 'Random blood glucose', 'Urea in blood',
#        'Serum Creatinine', 'Sodium in blood', 'Potassium in blood',
#        'Hemoglobin', 'Packed corpuscular volume', 'WBC count', 'RBC count',
#        'Apetite', 'Chronic kidney failure', 'PVC_Hb ratio', 'Anemia risk'],
#       dtype='object')

# %%
r= data['PVC_Hb ratio'].corr(data['Random blood glucose'])
print(f'correlation btw pvc hb ratio and chronic kideny failure: {r}')
# Out:
# correlation btw pvc hb ratio and chronic kideny failure: -0.0029463553851239617

# %% [markdown]
# there is negligible correlation between pvc hb ratio and random blood sugar values.

# %%
data_concat = pd.concat([df3, df2], axis=1)
data_concat.head()
# Out:
#    Patient ID   Age  Blood Pressure  Urine Specific Gravity  Albumin in urine  \
# 0         0.0  48.0           178.0                   10.10               2.0
# 1         1.0   7.0           138.0                   10.14               1.0
# 2         2.0  62.0           165.0                   10.14               2.0
# 3         3.0  48.0           141.0                   10.07               4.0
# 4         4.0  51.0           175.0                   10.15               4.0
#
#    Sugar in urine       RBC Puss cells Pus cells clumps Bacteria  ...  \
# 0             2.0  abnormal   abnormal          present  present  ...
# 1             4.0  abnormal   abnormal          present  present  ...
# 2             5.0  abnormal   abnormal          present  present  ...
# 3             4.0  abnormal   abnormal          present  present  ...
# 4             5.0  abnormal   abnormal          present  present  ...
#
# ...

# %%
df_merged = pd.merge(df2 , df3, on='Patient ID', how='inner')
df_merged.head()
# Out:
#    Patient ID  Age_x  Blood Pressure_x  Urine Specific Gravity_x  \
# 0           0     48               178                     10.10
# 1           1      7               138                     10.14
# 2           2     62               165                     10.14
# 3           3     48               141                     10.07
# 4           4     51               175                     10.15
#
#    Albumin in urine_x  Sugar in urine_x     RBC_x Puss cells_x  \
# 0                 2.0                 2  abnormal     abnormal
# 1                 1.0                 4  abnormal     abnormal
# 2                 2.0                 5  abnormal     abnormal
# 3                 4.0                 4  abnormal     abnormal
# 4                 4.0                 5  abnormal     abnormal
#
#   Pus cells clumps_x Bacteria_x  ...  Sodium in blood_y  Potassium in blood_y  \
# 0            present    present  ...              124.0                   6.0
# ...

# %%
df_joined = df1.join(df3, lsuffix='_l', rsuffix='_r',  how='left')
df_joined.head()
# Out:
#       Patient ID_l  Age_l  Blood Pressure_l  Urine Specific Gravity_l  \
# 190            190      6               130                     10.09
# 2070          2070      6               112                     10.22
# 3548          3548      6               113                     10.21
# 7982          7982      6                60                     11.91
# 9460          9460      6                60                     12.78
#
#       Albumin in urine_l  Sugar in urine_l     RBC_l Puss cells_l  \
# 190                  4.0                 2  abnormal     abnormal
# 2070                 0.0                 1  abnormal     abnormal
# 3548                 0.0                 0  abnormal     abnormal
# 7982               989.9               242  abnormal     abnormal
# 9460                20.0               199  abnormal     abnormal
#
#      Pus cells clumps_l Bacteria_l  ...  Sodium in blood_r  \
# 190             present    present  ...              122.0
# ...
